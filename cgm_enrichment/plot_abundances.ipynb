# %%
import matplotlib.pyplot as plt

# %%
data = np.genfromtxt("cgm_abundances.txt")
ref = data[1,:]
for i in range(1,data.shape[0]):
    plt.semilogy((data-ref)/ref*100, lw=1)
plt.ylabel("Abundance Deviation [%]")
plt.xlabel("Atomic Number")
# Out:
# Text(0.5, 0, 'Atomic Number')

# %%
fid = np.genfromtxt("dm_ev/cgm_dm_fid.txt")
plt.semilogy(np.linspace(0, 13, fid.size), fid, ls = '--')

for i in range(25):
    data = np.genfromtxt(f"dm_ev/cgm_dm_{i:03d}.txt")
    plt.semilogy(np.linspace(0, 13, data.size), data, ls="-")
    
plt.xlim(0,13)
plt.ylabel("DM Mass")
plt.xlabel("Time [Gyr]")
# Out:
# Text(0.5, 0, 'Time [Gyr]')
